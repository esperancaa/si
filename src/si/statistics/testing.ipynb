# %%
from cosine_distance import cosine_distance

x = [1, 2, 3]
y = [
    [4, 5, 6],
    [1, 0, 0],
    [0, 1, 1]
]
distances = cosine_distance(x, y)

print("Distâncias:", distances)
# Out:
# Distâncias: [array([0.82071571, 0.76095428, 0.73107356])]
